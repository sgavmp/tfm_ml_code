# %% [markdown]
# # Modelo 2 - Predicción de ingresos

# %% [markdown]
# ## Notebook para probar diferentes configuraciones y obtener el modelo.
# Este código lee los datos de ingresos que estan agregados en grupos de 28 días. Tenemos para cada día los ingresos de los 28 días previos. Los datos abarcan desde 2019-01-01 hasta el 2021-05-01.
# El planteamiento para el modelo es utiliza los n días previos para calcular los ingresos futuros.

# %% [markdown]
# # 0. Configuración

# %% [markdown]
# Instalar pycaret si fuese necesario

# %%
pip install pycaret
# Out:
# /opt/conda/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importamos las librerías necesarias

# %%
from pycaret.regression import *
import os
import datetime
import pandas as pd
S3=client('s3')

# %% [markdown]
# Esta variable define la ventana de n días previos a utilizar para predicir el valor actual.

# %%
window=27

# %% [markdown]
# # 1. Carga de datos

# %% [markdown]
# Cargamos el archivo CSV con los datos y parseamos el campo date como fecha.

# %%
dataset_raw = pd.read_csv('s3://tfm-2021-darwinex/data/model2/dataset_model2.csv', parse_dates=['date'])
dataset_raw.tail()
# Out:
#           date     commission
# 702 2021-04-12  286972.497651
# 703 2021-04-13  285758.616379
# 704 2021-04-14  284394.750251
# 705 2021-04-15  282975.681124
# 706 2021-04-16  281553.564786

# %%
dataset_raw.plot(x='date')
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# En base a la variable window, montamos el dataset necesario para el entrenamiento, obteniendo para cada día los n dias previos.

# %%
for i in range(1, window+1):
    col = 'lag_' + str(i)
    dataset_raw[col] = dataset_raw['commission'].shift(i)

# %%
dataset_raw.dropna(inplace=True)
dataset_raw.tail()
# Out:
#           date     commission          lag_1          lag_2          lag_3  \
# 702 2021-04-12  286972.497651  288187.058198  289457.120653  290647.615956
# 703 2021-04-13  285758.616379  286972.497651  288187.058198  289457.120653
# 704 2021-04-14  284394.750251  285758.616379  286972.497651  288187.058198
# 705 2021-04-15  282975.681124  284394.750251  285758.616379  286972.497651
# 706 2021-04-16  281553.564786  282975.681124  284394.750251  285758.616379
#
#              lag_4          lag_5          lag_6          lag_7  \
# 702  291791.882306  292960.251953  294281.562066  295596.039373
# 703  290647.615956  291791.882306  292960.251953  294281.562066
# 704  289457.120653  290647.615956  291791.882306  292960.251953
# 705  288187.058198  289457.120653  290647.615956  291791.882306
# 706  286972.497651  288187.058198  289457.120653  290647.615956
#
#              lag_8  ...         lag_18         lag_19         lag_20  \
# ...

# %% [markdown]
# # 2. Iniciar PyCaret

# %% [markdown]
# Inicializamos Pycaret con la función setup.
# Tras diversas pruebas hemos utilizado la siguiente configuración:
# - normalize = True: Sirve para normalizar cada columna del dataset.
# - transformation = True: Aplica las transofrmaciones para que los datos del dataset se ajusten mas a una campana de Gauss
# - ignore_features=['date']: Con esto indicamos que no queremos que utilice la columna date
# - target='commission': Aquñi indicamos que la variable que queremos predecir con el modelo
# - remove_outliers=True
# - remove_perfect_collinearity=False

# %%
exp_reg101 = setup(data = dataset_raw, normalize = True, ignore_features=['date'], data_split_shuffle=False, target = 'commission', remove_perfect_collinearity=False, silent=True)
# Out:
# <style  type="text/css" >
# #T_fb546_row27_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_fb546_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb546_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fb546_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_fb546_row0_col1" class="data row0 col1" >4428</td>
#             </tr>
#             <tr>
#                         <th id="T_fb546_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fb546_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_fb546_row1_col1" class="data row1 col1" >commission</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# # 3. Crear el modelo y elegir la mejor opción

# %% [markdown]
# Con la función *compare_models* ejecutamos la creación y comparación de los diferentes algoritmos que incluye Pycaret para Regression. Hemos indicado utilizar RMSLE en sort para que ordene la tabla por esta metrica. Consideramos que esta métrica, al ser un valor porcentual permite entender de una manera muy sencilla el tamaño del error. Esta función devuelve el modelo con mejor métrica.

# %%
best = compare_models(exclude = ['ransac'], sort='RMSLE')
# Out:
# <style  type="text/css" >
#     #T_0e5ad_ th {
#           text-align: left;
# ...

# %%
#best = create_model('llar')

# %% [markdown]
# # 4. Ajustar hiperparámetros

# %% [markdown]
# Utilizando la función *tune_model* hacemos que Pycaret obtenga y optimice los hyperparámetros del algoritmo utilizado.

# %%
best_tuned = tune_model(best)
# Out:
# <style  type="text/css" >
# #T_6e308_row10_col0,#T_6e308_row10_col1,#T_6e308_row10_col2,#T_6e308_row10_col3,#T_6e308_row10_col4,#T_6e308_row10_col5{
#             background:  yellow;
#         }</style><table id="T_6e308_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e308_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6e308_row0_col0" class="data row0 col0" >143.1292</td>
#                         <td id="T_6e308_row0_col1" class="data row0 col1" >33928.9141</td>
# ...

# %% [markdown]
# # 5. Probar modelo con datos de test

# %%
predict_new = predict_model(best_tuned)
# Out:
# <style  type="text/css" >
# </style><table id="T_637eb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_637eb_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_637eb_row0_col0" class="data row0 col0" >Linear Regression</td>
#                         <td id="T_637eb_row0_col1" class="data row0 col1" >186.1927</td>
#                         <td id="T_637eb_row0_col2" class="data row0 col2" >157196.7969</td>
# ...

# %% [markdown]
#  # 6. Mostrar información del modelo

# %% [markdown]
# Utilizando la función *plot_model* podemos visualizar diferentes métricas o graficas resultantes del modelo.

# %% [markdown]
# ## 6.1 Area Under the Curve

# %%
try:
    plot_model(calibrated_dt, plot='auc')
except Exception as ex:
    print("This model can't measure auc.")
# Out:
# This model can't measure auc.

# %% [markdown]
# ## 6.1 Area Under the Curve

# %%
plot_model(best_tuned, plot='residuals')

# %% [markdown]
# ## 6.1 Area Under the Curve

# %%
plot_model(best_tuned, plot = 'error')

# %% [markdown]
# ## 6.1 Area Under the Curve

# %%
plot_model(best_tuned, plot='feature')

# %% [markdown]
#  # 7. Finalizar y comparar el resultado

# %% [markdown]
# La función *finalize_model* da por temrminado el ajuste del modelo, utilizando para ello todos los datos del dataset utilizando al inicio, y no solo lo conjunto de entrenamiento.

# %%
final_model = finalize_model(best_tuned)

# %% [markdown]
# Utilizamos el modelo para calcular, utilizando el dataset original, los datos de cada día para comparar, visualmente, ambas lineas.

# %%
test_result = predict_model(final_model, dataset_raw)

# %%
test_result
# Out:
#           date     commission          lag_1          lag_2          lag_3  \
# 27  2019-02-17  148394.510378  147406.611720  146688.142986  146175.122106
# 28  2019-02-18  149344.843504  148394.510378  147406.611720  146688.142986
# 29  2019-02-19  150325.859191  149344.843504  148394.510378  147406.611720
# 30  2019-02-20  151420.824862  150325.859191  149344.843504  148394.510378
# 31  2019-02-21  152472.959751  151420.824862  150325.859191  149344.843504
# ..         ...            ...            ...            ...            ...
# 702 2021-04-12  286972.497651  288187.058198  289457.120653  290647.615956
# 703 2021-04-13  285758.616379  286972.497651  288187.058198  289457.120653
# 704 2021-04-14  284394.750251  285758.616379  286972.497651  288187.058198
# 705 2021-04-15  282975.681124  284394.750251  285758.616379  286972.497651
# 706 2021-04-16  281553.564786  282975.681124  284394.750251  285758.616379
#
#              lag_4          lag_5          lag_6          lag_7  \
# ...

# %%
test_result.plot(x='date', y=['commission', 'Label'])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## 8. Guardar modelo

# %%
save_model(final_model, model_name='model2', verbose=False)
S3.upload_file('model2.pkl', 'tfm-2021-darwinex', 'models/model2/final_model.pkl')
S3.upload_file('model2.pkl', 'tfm-2021-darwinex', 'models/model2/history/{}_model'.format(datetime.datetime.now()))

# %% [markdown]
# # 9. Predecimos dias futuros

# %%
df = test_result
df.date = pd.to_datetime(df.date)
df = df.set_index(df.date)

df['prediction'] = df['commission']
df['calculated'] = 0

dates_to_predict = pd.DataFrame(pd.date_range(start='2021-03-01', periods=180), columns=['date'])

columns = ['lag_' + str(i) for i in range(1, window+1)]
columns.reverse()

# %%
df
# Out:
#                  date     commission          lag_1          lag_2  \
# date
# 2019-02-17 2019-02-17  148394.510378  147406.611720  146688.142986
# 2019-02-18 2019-02-18  149344.843504  148394.510378  147406.611720
# 2019-02-19 2019-02-19  150325.859191  149344.843504  148394.510378
# 2019-02-20 2019-02-20  151420.824862  150325.859191  149344.843504
# 2019-02-21 2019-02-21  152472.959751  151420.824862  150325.859191
# ...               ...            ...            ...            ...
# 2021-04-12 2021-04-12  286972.497651  288187.058198  289457.120653
# 2021-04-13 2021-04-13  285758.616379  286972.497651  288187.058198
# 2021-04-14 2021-04-14  284394.750251  285758.616379  286972.497651
# 2021-04-15 2021-04-15  282975.681124  284394.750251  285758.616379
# 2021-04-16 2021-04-16  281553.564786  282975.681124  284394.750251
#
#                     lag_3          lag_4          lag_5          lag_6  \
# date
# 2019-02-17  146175.122106  145747.171624  145266.981897  144610.241986
# ...

# %%
for row in dates_to_predict.iterrows():
    if row[1][0].weekday() != 5:
        df_temp = df[df.index < row[1][0]].tail(n=window).transpose().iloc[[window+3]]
        df_temp.columns = columns
        prediction = predict_model(final_model, df_temp).iloc[0]['Label']
        new_row = pd.DataFrame({'prediction': prediction, 'calculated': 1}, index=[row[1][0]])
        if not df[df.index.isin([row[1][0]])].empty:
            df.update(new_row)
        else:
            df = df.append(new_row)
        df.sort_index(inplace=True)

# %%
df.tail(100)
# Out:
#            date  commission  lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  \
# 2021-05-04  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-05-05  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-05-06  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-05-07  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-05-09  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...         ...         ...    ...    ...    ...    ...    ...    ...    ...
# 2021-08-23  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-08-24  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-08-25  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-08-26  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-08-27  NaT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
df.plot(y=['commission', 'Label', 'prediction'], figsize=(20,10))
# Out:
# <AxesSubplot:>
